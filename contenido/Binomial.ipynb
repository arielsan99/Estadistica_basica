# %% [markdown]
# ## Función de densidad
# Sea $X = B(n = 30, p = 0.6)$,

# %%
install.packages('Rlab')
# Out:
# Warning message:
# "package 'Rlab' is in use and will not be installed"

# %%
library(Rlab)
n = 30
p = 0.6
plot(0:n, dbinom(0:n, size = n, prob = p))
plot(0:n, pbinom(0:n, size = n, prob = p))
qbinom(0.5, n, p)
qbinom(0.25, n, p)
hist(rbinom(100000, n, p), breaks = 0:30)
# Out:
# plot without title
# [1] 18
# [1] 16
# plot without title
# Plot with title "Histogram of rbinom(1e+05, n, p)"
